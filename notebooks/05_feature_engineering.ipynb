# %% [markdown]
# # 05 - Feature Engineering
#
# Feature engineering can often improve model performance by creating, transforming, or selecting useful features (e.g., applying non-linear transformation, interaction features, or doing feature selection).
#
# For simplicity, we'll skip this step in this demo and use the original feature set for all models.
