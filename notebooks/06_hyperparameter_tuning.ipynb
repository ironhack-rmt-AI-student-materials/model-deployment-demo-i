# %% [markdown]
# # 06 - Hyperparameter Tuning
#
# Hyperparameter tuning can often improve model performance by finding better model configurations (e.g., adjusting parameters like the maximum depth of decision trees, number of neighbors in KNN, regularization strength, etc.).
#
# For simplicity, we'll skip this step in this demo and use the default hyperparameters for all models.
